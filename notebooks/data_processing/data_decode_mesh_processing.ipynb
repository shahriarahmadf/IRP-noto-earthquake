# %%
# DATA LOADING

from mobility_data_loader import mobility_data_loader

def raw_data_mesh_decode(start_date,end_date):
    save_path = 'E:\\IRP_noto_earthquake\\data\\intermediate\\'

    df = mobility_data_loader(start_date,end_date)
    
    # Loop through all raw dataframe to process
    for day, dataframeDay in df.items():

        print(day)
        dataframeDay.to_csv(f'{save_path}{day}', index=False)
    
    return print('success')

# Process whole dataset into intermediate form
raw_data_mesh_decode('20240101','20240331')
# Out:
# 1
# 20240101 dataframe shape
# (85653, 18)
# 2
# 20240102 dataframe shape
# (84857, 18)
# 3
# 20240103 dataframe shape
# (85335, 18)
# 4
# 20240104 dataframe shape
# (101273, 18)
# 5
# 20240105 dataframe shape
# (113529, 18)
# 6
# 20240106 dataframe shape
# (104928, 18)
# 7
# 20240107 dataframe shape
# (94203, 18)
# 8
# 20240108 dataframe shape
# (91534, 18)
# 9
# 20240109 dataframe shape
# (115631, 18)
# 10
# 20240110 dataframe shape
# (115583, 18)
# 11
# 20240111 dataframe shape
# (117350, 18)
# 12
# 20240112 dataframe shape
# (119567, 18)
# 13
# 20240113 dataframe shape
# (106789, 18)
# 14
# 20240114 dataframe shape
# (99355, 18)
# 15
# 20240115 dataframe shape
# (114665, 18)
# 16
# 20240116 dataframe shape
# (115293, 18)
# 17
# 20240117 dataframe shape
# (119302, 18)
# 18
# 20240118 dataframe shape
# (115119, 18)
# 19
# 20240119 dataframe shape
# (122319, 18)
# 20
# 20240120 dataframe shape
# (110519, 18)
# 21
# 20240121 dataframe shape
# (95166, 18)
# 22
# ...

# %%
# Testing intermediate data
import pandas as pd

data = pd.read_csv('E:\\IRP_noto_earthquake\\data\\intermediate\\20240101')

# %%
data.head(
)
# Out:
#                           common_id  latitude_o  longitude_o  \
# 0  67e6401f1f6460684eed82521ce87f02   34.680007   135.575515
# 1  3275d92ef18f9a6eb22f4d90536a1404   33.805680   132.809934
# 2  f2aacb3154cc40a0445d6bbd911933b5   36.543807   136.620889
# 3  c21eeabbff24abdc6a5df55d524abc59   36.708401   137.359956
# 4  a86b7d031dc964a774127bd6776af940   35.352004   134.948453
#
#          arrive_time_o  stay_time_o        depart_time_o  move_time   mode  \
# 0  2023-12-31 22:16:24          104  2024-01-01 00:00:00         64  train
# 1  2023-12-31 23:27:53           32  2024-01-01 00:00:00          7    car
# 2  2023-12-31 14:18:01          582  2024-01-01 00:00:01       4086   walk
# 3  2023-12-31 23:36:55           23  2024-01-01 00:00:01          6   walk
# 4  2023-12-31 16:47:35          432  2024-01-01 00:00:02          6    car
#
#    latitude_d  longitude_d        arrive_time_d  stay_time_d  \
# 0   34.680177   135.575084  2024-01-01 01:04:15           66
# ...

# %%
data.columns
# Out:
# Index(['common_id', 'latitude_o', 'longitude_o', 'arrive_time_o',
#        'stay_time_o', 'depart_time_o', 'move_time', 'mode', 'latitude_d',
#        'longitude_d', 'arrive_time_d', 'stay_time_d', 'depart_time_d',
#        'purpose_flg', 'latitude_h', 'longitude_h', 'latitude_w',
#        'longitude_w'],
#       dtype='object')
